# %% [markdown]
# # Homework Starter — Stage 08 EDA
#
# Fill in the marked TODOs. This notebook generates synthetic data so you can focus on the EDA flow. Replace with your dataset when ready.

# %%
import numpy as np, pandas as pd, matplotlib.pyplot as plt, seaborn as sns
from scipy.stats import skew, kurtosis
sns.set(context='talk', style='whitegrid')
np.random.seed(8)
pd.set_option('display.max_columns', 100)

# === Synthetic data generator (adapt or replace with your own data) ===
n = 160
df = pd.DataFrame({
    'date': pd.date_range('2021-02-01', periods=n, freq='D'),
    'region': np.random.choice(['North','South','East','West'], size=n),
    'age': np.random.normal(40, 8, size=n).clip(22, 70).round(1),
    'income': np.random.lognormal(mean=10.6, sigma=0.3, size=n).round(2),
    'transactions': np.random.poisson(lam=3, size=n),
})
base = df['income'] * 0.0015 + df['transactions']*18 + np.random.normal(0, 40, size=n)
df['spend'] = np.maximum(0, base).round(2)

# inject a bit of missingness and outliers
df.loc[np.random.choice(df.index, 5, replace=False), 'income'] = np.nan
df.loc[np.random.choice(df.index, 3, replace=False), 'spend'] = np.nan
df.loc[np.random.choice(df.index, 2, replace=False), 'transactions'] = df['transactions'].max()+12
df.head()
# Out:
#         date region   age    income  transactions   spend
# 0 2021-02-01   West  37.6  28086.81             4   73.35
# 1 2021-02-02  North  43.0  33034.75             1   52.37
# 2 2021-02-03  South  38.2  50045.39             2  131.85
# 3 2021-02-04  South  24.9  39467.28             4  147.58
# 4 2021-02-05  South  59.8  31201.65             1   86.76

# %% [markdown]
# ## 1) First look

# %%
df.info(), df.isna().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 160 entries, 0 to 159
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          160 non-null    datetime64[ns]
#  1   region        160 non-null    object
#  2   age           160 non-null    float64
#  3   income        155 non-null    float64
#  4   transactions  160 non-null    int32
#  5   spend         157 non-null    float64
# dtypes: datetime64[ns](1), float64(3), int32(1), object(1)
# memory usage: 7.0+ KB
# (None,
#  date            0
#  region          0
#  age             0
#  income          5
#  transactions    0
#  spend           3
#  dtype: int64)

# %% [markdown]
# ## 2) Numeric profile

# %%
desc = df[['age','income','transactions','spend']].describe().T
desc['skew'] = [skew(df[c].dropna()) for c in desc.index]
desc['kurtosis'] = [kurtosis(df[c].dropna()) for c in desc.index]
desc
# Out:
#               count          mean           std       min       25%       50%  \
# age           160.0     40.018750      8.458676     22.00     34.70     40.15
# income        155.0  41983.866323  13262.457038  17928.80  32471.53  39332.52
# transactions  160.0      3.237500      2.585610      0.00      2.00      3.00
# spend         157.0    117.291592     51.768645      0.54     77.25    119.32
#
#                     75%       max      skew   kurtosis
# age              44.925     61.10  0.069538  -0.080125
# income        49697.690  87052.40  0.993336   0.918722
# transactions      4.000     20.00  3.466078  19.984802
# spend           153.340    280.05  0.130860  -0.084917

# %% [markdown]
# ## 3) Distributions (TODO: add at least 3)

# %%
numeric_cols = df.select_dtypes(include=['float64', 'int64']).columns
for col in numeric_cols[:3]:
    plt.figure(figsize=(6,4))
    sns.histplot(df[col].dropna(), kde=True, bins=30)
    plt.title(f"Distribution of {col}")
    plt.xlabel(col)
    plt.ylabel("Count")
    plt.show()
for col in numeric_cols[:3]:
    plt.figure(figsize=(6,4))
    sns.boxplot(x=df[col])
    plt.title(f"Boxplot of {col}")
    plt.show()

# %% [markdown]
# ## 4) Relationships (TODO: add at least 2)

# %%
if len(numeric_cols) >= 2:
    plt.figure(figsize=(6,4))
    sns.scatterplot(x=df[numeric_cols[0]], y=df[numeric_cols[1]])
    plt.title(f"Scatterplot: {numeric_cols[0]} vs {numeric_cols[1]}")
    plt.show()
if 'date' in df.columns:
    df['date'] = pd.to_datetime(df['date'])
    plt.figure(figsize=(10,4))
    sns.lineplot(x=df['date'], y=df[numeric_cols[0]])
    plt.title(f"Trend of {numeric_cols[0]} over time")
    plt.show()

# %% [markdown]
# ## 5) (Optional) Correlation matrix

# %%
corr = df[['age','income','transactions','spend']].corr(numeric_only=True)
sns.heatmap(corr, annot=True, fmt='.2f', cmap='vlag', vmin=-1, vmax=1)
plt.title('Correlation Matrix')
plt.show()
corr
# Out:
#                    age    income  transactions     spend
# age           1.000000 -0.123160      0.037754  0.008174
# income       -0.123160  1.000000      0.063573  0.307307
# transactions  0.037754  0.063573      1.000000  0.480685
# spend         0.008174  0.307307      0.480685  1.000000

# %% [markdown]
# ## 6) Insights & Assumptions (write your commentary)
# - TODO: Top 3 insights
# - TODO: Assumptions & risks
# - TODO: Next steps before modeling (cleaning & features)

# %% [markdown]
# The distribution of age is approximately normal, with most individuals clustered around the age of 40. Income is clearly right-skewed, with the majority of values concentrated between 30,000 and 50,000 but several very high earners above 70,000 standing out as outliers. The distribution of spend also shows moderate right skewness, centered near 120, with a small group of extreme spenders exceeding 200. When examining relationships, the scatterplot between age and income does not suggest a strong linear association, which implies that other unobserved factors may play a larger role in determining income levels.
# The analysis assumes that missing data are either minimal or occur completely at random, such that they do not systematically bias results. It also assumes that the recorded values are accurate and have no errors. So there are several risks associated with these findings. Outliers in both income and spend could distort summary statistics and influence downstream models. Skewness in the variables may also pose challenges for algorithms that assume normality. In addition, if the sample collection process did not capture a representative range of individuals, there may be biases that reduce the generalizability of results. These risks should be carefully addressed before moving forward.
# Implications for the next step include applying transformations, such as logarithmic scaling, to reduce skewness in income and spend. And should consider outlier handling strategies and use of robust models. Before modeling, it will be important to normalize or standardize numerical variables to ensure comparability across features.
